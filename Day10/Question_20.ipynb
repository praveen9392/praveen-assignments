# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # 1. Read csv file

# %%
bikes_df = pd.read_csv('bikes.csv')
bikes_df
# Out:
#            Date Unnamed: 1  Berri1   CSC  Mais1  Mais2  Parc  PierDup  \
# 0    01/01/2013      00:00       0     0      1      0     6        0
# 1    02/01/2013      00:00      69     0     13      0    18        0
# 2    03/01/2013      00:00      69     2     21      6    22        1
# 3    04/01/2013      00:00      80     0     22      4    16        0
# 4    05/01/2013      00:00      52     4     19      3    12        0
# ..          ...        ...     ...   ...    ...    ...   ...      ...
# 256  14/09/2013      00:00    2488  1494   1706   2911   979     1075
# 257  15/09/2013      00:00    2243  1749   1417   2933  1804     1459
# 258  16/09/2013      00:00    4206  2466   2799   5485  3272      855
# 259  17/09/2013      00:00    5506  3153   3563   6626  3882     1485
# 260  18/09/2013      00:00    1564  3330   1154   1803  4074     1759
#
#      Rachel1  Totem_Laurier
# 0          1              0
# 1          2              0
# 2          0              0
# ...

# %% [markdown]
# # 2. Check head

# %%
bikes_df.head()
# Out:
#          Date Unnamed: 1  Berri1  CSC  Mais1  Mais2  Parc  PierDup  Rachel1  \
# 0  01/01/2013      00:00       0    0      1      0     6        0        1
# 1  02/01/2013      00:00      69    0     13      0    18        0        2
# 2  03/01/2013      00:00      69    2     21      6    22        1        0
# 3  04/01/2013      00:00      80    0     22      4    16        0      125
# 4  05/01/2013      00:00      52    4     19      3    12        0       97
#
#    Totem_Laurier
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0

# %% [markdown]
# # 3. Check summary statistics

# %%
bikes_df.describe()
# Out:
#             Berri1          CSC        Mais1        Mais2         Parc  \
# count   261.000000   261.000000   261.000000   261.000000   261.000000
# mean   2743.390805  1221.858238  1757.590038  3224.130268  1669.425287
# std    2247.957848  1070.037364  1458.793882  2589.514354  1363.738862
# min       0.000000     0.000000     1.000000     0.000000     6.000000
# 25%     392.000000    12.000000   236.000000   516.000000   222.000000
# 50%    2771.000000  1184.000000  1706.000000  3178.000000  1584.000000
# 75%    4767.000000  2168.000000  3158.000000  5812.000000  3068.000000
# max    6803.000000  3330.000000  4716.000000  7684.000000  4103.000000
#
#            PierDup      Rachel1  Totem_Laurier
# count   261.000000   261.000000     261.000000
# mean   1152.885057  3084.425287    1858.793103
# std    1208.848429  2380.255540    1434.899574
# min       0.000000     0.000000       0.000000
# 25%      12.000000   451.000000     340.000000
# ...

# %% [markdown]
# # 4. plot the daily attendance of two tracks, 'Berri1', 'PierDup'

# %%
plt.figure(figsize=(12, 6))
plt.plot(bikes_df['Date'], bikes_df['Berri1'], label='Berri1', color='b',marker="o",markersize=3)
plt.plot(bikes_df['Date'], bikes_df['PierDup'], label='PierDup', color='g',marker="o",markersize=3)
plt.xlabel('Date')
plt.ylabel('Number of Bikes')
plt.title('Daily Attendance Berri1 vs PierDup')
plt.legend()
plt.show()

# %% [markdown]
# # 5. Check index , explore weekday_name attributes

# %%
bikes_df
# Out:
#            Date Unnamed: 1  Berri1   CSC  Mais1  Mais2  Parc  PierDup  \
# 0    01/01/2013      00:00       0     0      1      0     6        0
# 1    02/01/2013      00:00      69     0     13      0    18        0
# 2    03/01/2013      00:00      69     2     21      6    22        1
# 3    04/01/2013      00:00      80     0     22      4    16        0
# 4    05/01/2013      00:00      52     4     19      3    12        0
# ..          ...        ...     ...   ...    ...    ...   ...      ...
# 256  14/09/2013      00:00    2488  1494   1706   2911   979     1075
# 257  15/09/2013      00:00    2243  1749   1417   2933  1804     1459
# 258  16/09/2013      00:00    4206  2466   2799   5485  3272      855
# 259  17/09/2013      00:00    5506  3153   3563   6626  3882     1485
# 260  18/09/2013      00:00    1564  3330   1154   1803  4074     1759
#
#      Rachel1  Totem_Laurier
# 0          1              0
# 1          2              0
# 2          0              0
# ...

# %%
bikes_df['Date'] = pd.to_datetime(bikes_df['Date'], dayfirst=True)
bikes_df.set_index('Date', inplace=True)
bikes_df['Weekday'] = bikes_df.index.weekday 
bikes_df['Weekday_Name'] = bikes_df.index.day_name()

# %%
print(bikes_df[['Weekday', 'Weekday_Name']].head())
# Out:
#             Weekday Weekday_Name
# Date
# 2013-01-01        1      Tuesday
# 2013-01-02        2    Wednesday
# 2013-01-03        3     Thursday
# 2013-01-04        4       Friday
# 2013-01-05        5     Saturday

# %%
bikes_df
# Out:
#            Unnamed: 1  Berri1   CSC  Mais1  Mais2  Parc  PierDup  Rachel1  \
# Date
# 2013-01-01      00:00       0     0      1      0     6        0        1
# 2013-01-02      00:00      69     0     13      0    18        0        2
# 2013-01-03      00:00      69     2     21      6    22        1        0
# 2013-01-04      00:00      80     0     22      4    16        0      125
# 2013-01-05      00:00      52     4     19      3    12        0       97
# ...               ...     ...   ...    ...    ...   ...      ...      ...
# 2013-09-14      00:00    2488  1494   1706   2911   979     1075     3277
# 2013-09-15      00:00    2243  1749   1417   2933  1804     1459     3623
# 2013-09-16      00:00    4206  2466   2799   5485  3272      855     4307
# 2013-09-17      00:00    5506  3153   3563   6626  3882     1485     5332
# 2013-09-18      00:00    1564  3330   1154   1803  4074     1759     1511
#
#             Totem_Laurier  Weekday Weekday_Name
# Date
# ...

# %% [markdown]
# # 6. Get sum of all attendance as a function of the weekday

# %%
attendance = bikes_df.groupby(bikes_df['Weekday']).sum()
attendance
# Out:
#                                                 Unnamed: 1  Berri1    CSC  \
# Weekday
# 0        00:0000:0000:0000:0000:0000:0000:0000:0000:000...  106826  51646
# 1        00:0000:0000:0000:0000:0000:0000:0000:0000:000...  117244  54656
# 2        00:0000:0000:0000:0000:0000:0000:0000:0000:000...  120434  59604
# 3        00:0000:0000:0000:0000:0000:0000:0000:0000:000...  115193  52340
# 4        00:0000:0000:0000:0000:0000:0000:0000:0000:000...  105701  44252
# 5        00:0000:0000:0000:0000:0000:0000:0000:0000:000...   75754  27226
# 6        00:0000:0000:0000:0000:0000:0000:0000:0000:000...   74873  29181
#
#          Mais1   Mais2   Parc  PierDup  Rachel1  Totem_Laurier  \
# Weekday
# 0        68087  129982  69767    44500   119211          72883
# 1        76974  141217  74299    40679   123533          76559
# 2        79033  145860  80437    42564   125173          79501
# 3        76273  141424  73668    36349   120684          74540
# ...

# %% [markdown]
# # 7. Display this in figure , what is the inference?

# %%
bikes_df.groupby('Weekday_Name').sum().reindex(
    ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
).plot(kind='bar', figsize=(10, 6), color=['b', 'g'])
plt.xlabel('Day of the Week')
plt.ylabel('Total Bikes')
plt.title('Total Attendance by Weekday')
plt.show()

# %% [markdown]
# # 20_B. Titanic-https://www.kaggle.com/c/titanic/data
# Database of whether somebody survived or not
# Can you infer who has survived ?

# %%
df = pd.read_csv('titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # 2. Which gender survived more

# %%
df.groupby('Sex')['Survived'].sum()
# Out:
# Sex
# female    233
# male      109
# Name: Survived, dtype: int64

# %%
df.groupby('Sex')['Survived'].sum().head(1)
# Out:
# Sex
# female    233
# Name: Survived, dtype: int64

# %% [markdown]
# # 3. Does it depend on pclass?

# %%
df.groupby('Pclass')['Survived'].sum()
# Out:
# Pclass
# 1    136
# 2     87
# 3    119
# Name: Survived, dtype: int64

# %% [markdown]
# # 4. can we see % of survival of each gender and pclass
# What is your inference?

# %%
df.groupby(['Sex', 'Pclass'])['Survived'].mean() * 100
# Out:
# Sex     Pclass
# female  1         96.808511
#         2         92.105263
#         3         50.000000
# male    1         36.885246
#         2         15.740741
#         3         13.544669
# Name: Survived, dtype: float64

# %% [markdown]
# # 20_C. Roger Federer database Each row corresponds to a ATP match played by Roger Federer Can you infer anything on Roger Federer performance?

# %%
federer = pd.read_csv('federer.csv')
print(federer.info())
print(federer.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1179 entries, 0 to 1178
# Data columns (total 70 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   year                                   1179 non-null   int64
#  1   tournament                             1179 non-null   object
#  2   start date                             1179 non-null   object
#  3   type                                   1179 non-null   object
#  4   surface                                1179 non-null   object
#  5   draw                                   1179 non-null   object
#  6   atp points                             1139 non-null   object
#  7   atp ranking                            1177 non-null   float64
#  8   tournament prize money                 1170 non-null   object
#  9   round                                  1179 non-null   object
# ...

# %% [markdown]
# # 2. How many % of matched won by our player? ('winner')

# %%
matches=federer.shape[0]
matches_won=federer[federer['winner']=='Roger Federer'].shape[0]
win_percentage=(matches_won/matches)*100
print(f"Percentage of matches won by Roger Federer: {win_percentage:.2f}%")
matches_won
# Out:
# Percentage of matches won by Roger Federer: 82.44%
# 972

# %% [markdown]
# # 3. Proportion of double faults wrt total points in each match

# %%
federer['Double_faults']=federer['player1 double faults']/federer['player1 total points total']
Double_faults=federer['Double_faults']
print(Double_faults)
# Out:
# 0       0.019417
# 1       0.000000
# 2       0.020270
# 3       0.046154
# 4            NaN
#           ...
# 1174    0.018116
# 1175    0.000000
# 1176    0.000000
# 1177    0.011561
# 1178         NaN
# Name: Double_faults, Length: 1179, dtype: float64

# %% [markdown]
# # 4. Average Win per surface

# %%
Avg_wps=federer[federer['winner']=='Roger Federer'].groupby('surface').size()
print(Avg_wps)
# Out:
# surface
# Indoor: Carpet     56
# Indoor: Clay        5
# Indoor: Hard      189
# Outdoor: Clay     194
# Outdoor: Grass    122
# Outdoor: Hard     406
# dtype: int64

# %% [markdown]
# # 5. Display the proportion of double faults as a function of the tournament date, 'start date' Trend: display average double faults in each year

# %%
federer['start date']=pd.to_datetime(federer['start date'],errors='coerce')
federer['year']=federer['start date'].dt.year
Avg_by_year=federer.groupby('year')['Double_faults'].mean()
print(Avg_by_year)
# Out:
# year
# 1998.0    0.020738
# 1999.0    0.028285
# 2000.0    0.020918
# 2001.0    0.016780
# 2002.0    0.016084
# 2003.0    0.018211
# 2004.0    0.012856
# 2005.0    0.008778
# 2006.0    0.008495
# 2007.0    0.009116
# 2008.0    0.005306
# 2009.0    0.008313
# 2010.0    0.009711
# 2011.0    0.008275
# 2012.0    0.011024
# Name: Double_faults, dtype: float64

# %% [markdown]
# # 20_D. Create two frequencies 5Hz and 50Hz sin signals Draw FFT components

# %%
from scipy.fft import fft, fftfreq

Fs = 500
t = np.linspace(0, 1, Fs)
signal = np.sin(2*np.pi*5*t) + np.sin(2*np.pi*50*t)

fft_values = fft(signal)
freqs = fftfreq(Fs, 1/Fs)
plt.plot(freqs[:Fs//2], np.abs(fft_values[:Fs//2]))
plt.title('FFT of 5Hz + 50Hz Signal')
plt.xlabel('Frequency')
plt.ylabel('Magnitude')
plt.show()

# %% [markdown]
# # 20_E. Plotting normal random numbers and show that addition of two Gaussian is Gaussian and addition of all is Gaussian

# %%
x1 = np.random.normal(0, 1, 10000)
x2 = np.random.normal(2, 1, 10000)
x3 = np.random.normal(5, 2, 10000)

plt.hist(x1 + x2, bins=50, alpha=0.6, label='x1 + x2')
plt.hist(x1 + x2 + x3, bins=50, alpha=0.6, label='x1 + x2 + x3')
plt.legend()
plt.title('Sum of Gaussians')
plt.show()
